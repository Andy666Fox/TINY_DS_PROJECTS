# %% [markdown]
# # IMPORTS

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # DATA READ

# %%
data = pd.read_csv('./input/flipkart.csv')
data[data['brand'] != 'Apple']
# Out:
#       brand          model base_color  ROM  RAM processor  display_size  \
# 56     Poco             C3      Black   64    4  MediaTek           6.5
# 57     Poco             M3       Blue   64    4  Qualcomm           6.5
# 58     Poco    M2 Reloaded       Blue   64    4  MediaTek           6.5
# 59     Poco             C3       Blue   32    3  MediaTek           6.5
# 60     Poco             M3      Black   64    6  Qualcomm           6.5
# ..      ...            ...        ...  ...  ...       ...           ...
# 425  Xiaomi    Redmi 6 Pro      Black   32    3  Qualcomm           5.8
# 426  Xiaomi    Redmi 6 Pro        Red   64    4  Qualcomm           5.8
# 427  Xiaomi     Mi 11 Lite     Others  128    6  Qualcomm           6.5
# 428  Xiaomi  Redmi 8A Dual       Blue   32    3  Qualcomm           6.2
# 429  Xiaomi    Redmi 6 Pro       Blue   32    3  Qualcomm           5.8
#
#     screen_size  num_rear_camera  num_front_camera  battery_capacity  ratings  \
# ...

# %%
data.head(10)

# %% [markdown]
# # EDA BLOCK

# %%
data.describe()
# Out:
#               ROM         RAM  display_size  num_rear_camera  \
# count  430.000000  430.000000    430.000000       430.000000
# mean   105.748837    5.320930      6.369767         2.904651
# std     63.164064    2.182635      0.369549         0.952350
# min      8.000000    1.000000      4.700000         1.000000
# 25%     64.000000    4.000000      6.300000         2.000000
# 50%    128.000000    4.000000      6.500000         3.000000
# 75%    128.000000    6.000000      6.500000         4.000000
# max    512.000000   12.000000      7.600000         4.000000
#
#        num_front_camera  battery_capacity     ratings  num_of_ratings  \
# count        430.000000        430.000000  430.000000      430.000000
# mean           1.044186       4529.397674    4.339302    89234.651163
# std            0.227280        986.907252    0.151494   150949.499518
# min            1.000000       1800.000000    3.000000       10.000000
# ...

# %% [markdown]
# # PLOTTING

# %%
f, ax = plt.subplots(figsize=(16,12))
sns.heatmap(data.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(figsize=(14,10))
ax.set_title('DISTR OF RATINGS', fontsize=16)
ax.set_xlabel("RATING", fontsize=16)
ax.set_ylabel('DISTR', fontsize=16)

data['ratings'].value_counts().plot(ax=ax, kind='bar', color='red')
# Out:
# <AxesSubplot:title={'center':'DISTR OF RATINGS'}, xlabel='RATING', ylabel='DISTR'>

# %%
fig,ax = plt.subplots(figsize=(20,10))

for elem in data.columns:
    try:
        sns.scatterplot(ax=ax, x=data[elem], y=data['ratings'])
    except:
        print('ЪуЪ')
